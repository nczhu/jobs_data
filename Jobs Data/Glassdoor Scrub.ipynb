# %%
import pandas as pd
import numpy as np
import math as m
import re


#imported from import.io -> eventually replace with scrapy
raw = pd.read_csv("Salary data - Raw - Glassdoor.csv")

# %%
#deleting useless cols and renaming cols for better readability
if 'Sqlogolink image_alt' in raw: del raw['Sqlogolink image_alt']
if 'Nomargvert link_link' in raw: del raw['Nomargvert link_link']
if 'Small link' in raw: del raw['Small link']
if 'Small link_link' in raw: del raw['Small link_link']

raw.columns = ['source_url', 'image_url', 'company_page', 'role', 'company_name', 'salary_count', 'salary', 'pay_period', 'pay_min','pay_max']
raw.drop_duplicates()

# check for any critical missing values, if so fill or drop from table
raw.apply(lambda x: sum(x.isnull()),axis=0)
# raw['col_name'].fillna(some_value, inplace=True)
# Out:
# source_url        0
# image_url       113
# company_page    113
# role              0
# company_name      0
# salary_count      0
# salary            0
# pay_period        0
# pay_min           0
# pay_max           0
# dtype: int64

# %%
# Standardization of cols, converting to correct formating.
from currency_converter import CurrencyConverter
c = CurrencyConverter()

def std_role(role):   
    return re.sub('\s\-\s\w*', '', role, flags=re.IGNORECASE)

# removes " (Singapore)" from company names - Glassdoor specific issue
def std_company_name(company_name):   
    return re.sub('\s\(Singapore\)', '', company_name, flags=re.IGNORECASE)

def std_salary_count(salary_count):
    return [int(s) for s in salary_count.split() if s.isdigit()][0]

# "40k-50k" range returns the average(min,max)
def std_salary(salary):
    salary = re.sub('[\,\$]','',salary)   # strips $ and ,
    salary = re.sub('k','000',salary)
    if '-' in salary: 
        min_max_salary = map(int, re.split('\-',salary))
        return int(sum(min_max_salary)/2)
    else: return int(salary)

raw['role'] = raw['role'].apply(std_role)
raw['company_name'] = raw['company_name'].apply(std_company_name)
raw['salary_count'] = raw['salary_count'].apply(std_salary_count)
raw['salary'] = raw['salary'].apply(std_salary)
raw['pay_min'] = raw['pay_min'].apply(std_salary)
raw['pay_max'] = raw['pay_max'].apply(std_salary)

# standardizing the pay period to get monthly and yearly pays
def std_to_year(period, salary, output): 
    if output is 'year': 
        if 'monthly' in period:return salary*12
        else: return salary
    else: 
        if 'monthly' in period: return salary
        else: return int(salary/12)
    
    
raw['yearly'] = raw.apply(lambda row: std_to_year(row['pay_period'], row['salary'],'year'), axis=1)
raw['yearly_min'] = raw.apply(lambda row: std_to_year(row['pay_period'], row['pay_min'],'year'), axis=1)
raw['yearly_max'] = raw.apply(lambda row: std_to_year(row['pay_period'], row['pay_max'],'year'), axis=1)
raw['monthly'] = raw.apply(lambda row: std_to_year(row['pay_period'], row['salary'],'month'), axis=1)
raw['monthly_min'] = raw.apply(lambda row: std_to_year(row['pay_period'], row['pay_min'],'month'), axis=1)
raw['monthly_max'] = raw.apply(lambda row: std_to_year(row['pay_period'], row['pay_max'],'month'), axis=1)

if 'salary' in raw: del raw['salary']
if 'pay_period' in raw: del raw['pay_period']
if 'pay_min' in raw: del raw['pay_min']
if 'pay_max' in raw: del raw['pay_max']

raw = raw[['company_name', 'role', 'salary_count', 'yearly', 'yearly_min', 'yearly_max','monthly','monthly_min','monthly_max','company_page','source_url','image_url']]
raw = raw.sort_values('company_name')
raw
# Out:
#                company_name                           role  salary_count  \
# 183              2359 Media              Software Engineer             2
# 45               2359 Media      Senior Software Developer             1
# 709              2359 Media      Senior Software Developer             1
# 419              2359 Media              Software Engineer             1
# 401                    3Com              Software Engineer             1
# 549                      3M    Principal Software Engineer             1
# 508               701Search              Software Engineer             1
# 781                  A*Star      Software Developer Intern             1
# 558                  A*Star        Senior Software Analyst             1
# 268  A-IT Software Services                       Software             1
# 678         A2000 Solutions       Senior Software Engineer             1
# 476                 ACTAtek              Software Engineer             1
# 776                     AIG  Software Developer Contractor             1
# 582                     AMD       Senior Software Engineer             1
# 583                     AMD       Senior Software Engineer             1
# 296                     AMD           Software Engineer II             1
# 348                     AMD       Software Engineer Intern             1
# 500                 AP Link       Software Engineer Intern             1
# 448                     ASM              Software Engineer             1
# 147  ASM Pacific Technology       Senior Software Engineer             3
# 35   ASM Pacific Technology              Software Engineer             6
# 95   ASM Pacific Technology              Software Engineer             6
# 812        ASM Technologies    Software Development Intern             1
# 399     Abercrombie & Fitch              Software Engineer             1
# 642               Accellion       Senior Software Engineer             1
# 382               Accellion              Software Engineer             1
# 383               Accellion              Software Engineer             1
# 706               Accellion      Senior Software Developer             1
# 86                Accenture       Senior Software Engineer             7
# 140               Accenture       Senior Software Engineer             3
# ..                      ...                            ...           ...
# 309                   Xfers    Software Engineering Intern             1
# 342                  Xilinx              Software Engineer             1
# 453                Xunlight              Software Engineer             1
# 316                   Yahoo              Software Engineer             1
# 568                   Yahoo       Senior Software Engineer             1
# 25                 Yokogawa              Software Engineer             7
# 176                Yokogawa              Software Engineer             2
# 85                 Yokogawa              Software Engineer             7
# 241                Yokogawa       Senior Software Engineer             2
# 436                  Zalora   Software Engineer Contractor             1
# 435                  Zalora              Software Engineer             1
# 261                  Zalora             Software Developer             2
# 297      Zebra Technologies           Software Engineer II             1
# 70                  Zendesk              Software Engineer             4
# 110                 Zendesk              Software Engineer             4
# 791                  Zyllem             Software Developer             1
# 516                addvalue              Software Engineer             1
# 789                   buUuk             Software Developer             1
# 527                   ezbuy              Software Engineer             1
# 492                    gumi              Software Engineer             1
# 796                     i2R      Software Developer Intern             1
# 505  i2s Business Solutions              Software Engineer             1
# 790                   iTwin             Software Developer             1
# 466                 inKline              Software Engineer             1
# 145                   mig33       Senior Software Engineer             3
# 412                   mig33              Software Engineer             1
# 626      muvee Technologies       Senior Software Engineer             1
# 189      muvee Technologies              Software Engineer             2
# 228      muvee Technologies       Senior Software Engineer             2
# 543            tenCube Inc.      Product Software Engineer             1
#
#      yearly  yearly_min  yearly_max  monthly  monthly_min  monthly_max  \
# 183   42000       36000       48000     3500         3000         4000
# 45    54000       48000       60000     4500         4000         5000
# 709   54000       48000       60000     4500         4000         5000
# 419   52000       50000       54000     4333         4166         4500
# 401   40500       39000       42000     3375         3250         3500
# 549  120000      120000      120000    10000        10000        10000
# 508   54000       48000       60000     4500         4000         5000
# 781    9600        9228        9984      800          769          832
# 558   60000       60000       60000     5000         5000         5000
# 268  108000      108000      108000     9000         9000         9000
# 678   36000       36000       36000     3000         3000         3000
# 476   36000       36000       36000     3000         3000         3000
# 776   42000       36000       48000     3500         3000         4000
# 582   60000       60000       60000     5000         5000         5000
# 583   64500       62000       67000     5375         5166         5583
# 296   48000       48000       48000     4000         4000         4000
# 348   18000       12000       24000     1500         1000         2000
# 500    9588        9132       10044      799          761          837
# 448   36000       36000       36000     3000         3000         3000
# 147   58404       48000       60000     4867         4000         5000
# 35    40656       36000       48000     3388         3000         4000
# 95    40656       36000       48000     3388         3000         4000
# 812    7236        6936        7548      603          578          629
# 399   48000       48000       48000     4000         4000         4000
# 642   94500       90000       99000     7875         7500         8250
# 382   48000       48000       48000     4000         4000         4000
# 383   48000       46000       50000     4000         3833         4166
# 706  102000       96000      108000     8500         8000         9000
# 86    57309       50000       64000     4775         4166         5333
# 140   53124       48000       60000     4427         4000         5000
# ..      ...         ...         ...      ...          ...          ...
# 309   18000       12000       24000     1500         1000         2000
# 342   42000       36000       48000     3500         3000         4000
# 453   36000       36000       36000     3000         3000         3000
# 316   75500       72000       79000     6291         6000         6583
# 568   89500       86000       93000     7458         7166         7750
# 25    41616       36000       60000     3468         3000         5000
# 176   43500       37000       50000     3625         3083         4166
# 85    41616       36000       60000     3468         3000         5000
# 241   66000       60000       72000     5500         5000         6000
# 436   36000       36000       36000     3000         3000         3000
# 435   66000       60000       72000     5500         5000         6000
# 261   72000       36000      108000     6000         3000         9000
# 297   48000       48000       48000     4000         4000         4000
# 70    72000       51000       85000     6000         4250         7083
# 110   72000       51000       85000     6000         4250         7083
# 791   54000       48000       60000     4500         4000         5000
# 516   36000       36000       36000     3000         3000         3000
# 789   54000       48000       60000     4500         4000         5000
# 527   48000       48000       48000     4000         4000         4000
# 492   54000       48000       60000     4500         4000         5000
# 796   11712       11424       12000      976          952         1000
# 505   36000       36000       36000     3000         3000         3000
# 790   48000       48000       48000     4000         4000         4000
# 466   24000       24000       24000     2000         2000         2000
# 145   70332       48000       84000     5861         4000         7000
# 412   72000       72000       72000     6000         6000         6000
# 626   36000       36000       36000     3000         3000         3000
# 189   42000       36000       48000     3500         3000         4000
# 228   62500       58000       67000     5208         4833         5583
# 543   30000       24000       36000     2500         2000         3000
#
#                                           company_page  \
# 183  https://www.glassdoor.com/Salary/2359-Media-Sa...
# 45   https://www.glassdoor.com/Salary/2359-Media-Sa...
# 709  https://www.glassdoor.com/Salary/2359-Media-Sa...
# 419  https://www.glassdoor.com/Salary/2359-Media-Sa...
# 401  https://www.glassdoor.com/Salary/3Com-Salaries...
# 549  https://www.glassdoor.com/Salary/3M-Salaries-E...
# 508                                                NaN
# 781  https://www.glassdoor.com/Salary/A-Star-Salari...
# 558  https://www.glassdoor.com/Salary/A-Star-Salari...
# 268  https://www.glassdoor.com/Salary/A-IT-Software...
# 678                                                NaN
# 476                                                NaN
# 776  https://www.glassdoor.com/Salary/AIG-Salaries-...
# 582  https://www.glassdoor.com/Salary/AMD-Salaries-...
# 583  https://www.glassdoor.com/Salary/AMD-Salaries-...
# 781  https://media.glassdoor.com/sqls/254781/a-star...
# 558  https://media.glassdoor.com/sqls/254781/a-star...
# 268  https://media.glassdoor.com/sqls/583171/a-it-s...
# 678                                                NaN
# 476                                                NaN
# 776  https://media.glassdoor.com/sqls/40/aig-square...
# 582  https://media.glassdoor.com/sqls/15/amd-square...
# 583  https://media.glassdoor.com/sqls/15/amd-square...
# 296  https://media.glassdoor.com/sqls/15/amd-square...
# 348  https://media.glassdoor.com/sqls/15/amd-square...
# 500                                                NaN
# 448  https://media.glassdoor.com/sqls/373497/asm-sq...
# 147  https://media.glassdoor.com/sqls/40486/asm-pac...
# 35   https://media.glassdoor.com/sqls/40486/asm-pac...
# 95   https://media.glassdoor.com/sqls/40486/asm-pac...
# 812  https://media.glassdoor.com/sqls/342007/asm-te...
# 399  https://media.glassdoor.com/sqls/6756/abercrom...
# 642  https://media.glassdoor.com/sqls/23755/accelli...
# 382  https://media.glassdoor.com/sqls/23755/accelli...
# 383  https://media.glassdoor.com/sqls/23755/accelli...
# 706  https://media.glassdoor.com/sqls/23755/accelli...
# 86   https://media.glassdoor.com/sqls/4138/accentur...
# 140  https://media.glassdoor.com/sqls/4138/accentur...
# ..                                                 ...
# 309                                                NaN
# 342  https://media.glassdoor.com/sqls/2063/xilinx-s...
# 453  https://media.glassdoor.com/sqls/276467/xunlig...
# 316  https://media.glassdoor.com/sqls/5807/yahoo-sq...
# 568  https://media.glassdoor.com/sqls/5807/yahoo-sq...
# 25   https://media.glassdoor.com/sqls/8192/yokogawa...
# 176  https://media.glassdoor.com/sqls/8192/yokogawa...
# 85   https://media.glassdoor.com/sqls/8192/yokogawa...
# 241  https://media.glassdoor.com/sqls/8192/yokogawa...
# 436  https://media.glassdoor.com/sqls/585411/zalora...
# 435  https://media.glassdoor.com/sqls/585411/zalora...
# 261  https://media.glassdoor.com/sqls/585411/zalora...
# 297  https://media.glassdoor.com/sqls/2089/zebra-te...
# 70   https://media.glassdoor.com/sqls/360923/zendes...
# 110  https://media.glassdoor.com/sqls/360923/zendes...
# 791                                                NaN
# 516  https://media.glassdoor.com/sqls/1111078/addva...
# 789                                                NaN
# 527                                                NaN
# 492                                                NaN
# 796  https://media.glassdoor.com/sqls/332480/i2r-sq...
# 505  https://media.glassdoor.com/sqls/655611/i2s-bu...
# 790                                                NaN
# 466                                                NaN
# 145  https://media.glassdoor.com/sqls/229883/mig33-...
# 412  https://media.glassdoor.com/sqls/229883/mig33-...
# 626                                                NaN
# 189                                                NaN
# 228                                                NaN
# 543                                                NaN
#
# [826 rows x 12 columns]

# %%
# deduplicate same roles from the same company

raw.groupby(level=['company_name', 'role'])
# if company name and role name are same, combine two cols
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c55a3efb0658> in <module>()
#       1 # deduplicate same roles from the same company
#       2
# ----> 3 raw.groupby(level=['company_name', 'role'])
#       4 # if company name and role name are same, combien two cols
#
# /Users/nicole/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /Users/nicole/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1425         raise TypeError('invalid type: %s' % type(obj))
#    1426
# -> 1427     return klass(obj, by, **kwds)
#    1428
#    1429
#
# /Users/nicole/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     352                                                     level=level,
#     353                                                     sort=sort,
# --> 354                                                     mutated=self.mutated)
#     355
#     356         self.obj = obj
#
# /Users/nicole/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2303                     raise ValueError('level name %s is not the name of the '
#    2304                                      'index' % level)
# -> 2305             elif level > 0:
#    2306                 raise ValueError('level > 0 only valid with MultiIndex')
#    2307
#
# TypeError: unorderable types: list() > int()

# %%
# Normalization
# normalize the roles etc.

# %%
# bring in the other sources

# %%
# Clustering multiple sources

# cluster the same companies together

# %% [raw]
# # Much later:
#
# # FUNCTION: Get link to detailed salary pages for Singapore based jobs
# # INPUT: https://www.glassdoor.com/Salary/Hewlett-Packard-Singapore-Salaries-EI_IE327.0,15_IL.16,25_IN217.htm
# # OUTPUT: https://www.glassdoor.com/Salary/Hewlett-Packard-Singapore-Salaries-EI_IE327.0,3_IL.24,3_IN217.htm?filter.jobTitleFTS=engineer
# # syntax rule is company_code: E327 > transformed_code: EI_IE(company_code) + ".0,3_IL.24,3_IN217.htm"
# # url = "singapore" ...+ transformed_code
#
# https://www.glassdoor.com/Salary/CrimsonLogic-Singapore-Salaries-E32313.htm?filter.jobTitleFTS=engineer
# https://www.glassdoor.com/Salary/JDSU-Singapore-Salaries-EI_IE3589.0,4_IL.5,14_IN217.htm?filter.jobTitleFTS=engineer
# https://www.glassdoor.com/Salary/JDSU-Singapore-Salaries-E3589.htm?filter.jobTitleFTS=engineer
# https://www.glassdoor.com/Salary/CrimsonLogic-Singapore-Salaries-EI_IE32313.0,12_IL.13,22_IN217.htm?filter.jobTitleFTS=engineer

# %% [markdown]
# Appendix: index of technical roles
#
#
# Software Engineering
# 	Backend Engineer
# 	Build/Release Engineer
# 	Data Engineer
# 	Database Administrator
# 	DevOps Engineer
# 	Embedded Engineer
# 	Engineering Manager
# 	Frontend Engineer
# 	Full Stack Engineer
# 	Machine Learning Engineer
# 	Mobile Engineer
# 	QA/Test Engineer
# 	Security Engineer
# 	UX Engineer
#
# Data Science
# 	Data Analyst
# 	Data Scientist
#
#
# -----To be used later-----
# Product Management
# 	Product Manager
#
# Design
# 	Brand/Graphic Designer
# 	Product Designer
# 	UX Designer
# 	UX Researcher
# 	Visual/UI Designer
#
# Sales
# 	Account Executive
# 	Account Manager
# 	Business Development
# 	Customer Success Manager
# 	Sales Development Rep
# 	Sales Engineer
# 	Sales Manager
# 	Sales Operations
#
# Marketing
# 	Acquisition Marketing
# 	Brand Marketing
# 	Community/Events Marketing
# 	Content Marketing
# 	Lifecycle/Email Marketing
# 	Marketing Analytics &amp; Ops
# 	Marketing Programs
# 	PR / Communications
# 	Product Marketing
#
# Recruiting / People Ops
# 	HR Business Partner
# 	People Ops Management
# 	People Ops Specialist
# 	Recruiter
# 	Recruiting Coordinator
# 	Sourcer
#
#
# 	Accounting
# 	Financial Management / Analysis
# 	General Management
# 	Office Administration
#
# Other
